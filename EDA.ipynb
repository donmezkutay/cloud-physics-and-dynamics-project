# %% [markdown]
# ## 0. Import Libraries

# %%
from glob import glob

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import xarray as xr

# %% [markdown]
# ## 1. Open Data

# %%
# general path
path_general = 'data'

# data path
path_data = glob(fr'{path_general}/original_*')

# find datasets using glob
dt_era5 = xr.open_mfdataset(path_data, parallel=True)

# %%
dt_era5
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 85, latitude: 33, time: 44160)
# Coordinates:
#   * longitude  (longitude) float32 25.0 25.25 25.5 25.75 ... 45.5 45.75 46.0
#   * latitude   (latitude) float32 43.0 42.75 42.5 42.25 ... 35.5 35.25 35.0
#   * time       (time) datetime64[ns] 2001-06-01 ... 2020-08-31T23:00:00
# Data variables:
#     t2m        (time, latitude, longitude) float32 dask.array<chunksize=(22080, 33, 85), meta=np.ndarray>
#     blh        (time, latitude, longitude) float32 dask.array<chunksize=(22080, 33, 85), meta=np.ndarray>
#     cbh        (time, latitude, longitude) float32 dask.array<chunksize=(22080, 33, 85), meta=np.ndarray>
#     tcc        (time, latitude, longitude) float32 dask.array<chunksize=(22080, 33, 85), meta=np.ndarray>
#     tp         (time, latitude, longitude) float32 dask.array<chunksize=(22080, 33, 85), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
# ...

# %%
# get variable names
name_variables = [var for var in dt_era5.data_vars]

# %% [markdown]
# ## 2. Decompose Variables

# %%
for var_idx in range(len(name_variables)):
    
    # save nc variable data
    dt_era5[name_variables[var_idx]].to_netcdf(fr'{path_general}/{name_variables[var_idx]}_era5_2001_2020.nc')
    print('done', name_variables[var_idx])
# Out:
# done t2m
# done blh
# done cbh
# done tcc
# done tp
